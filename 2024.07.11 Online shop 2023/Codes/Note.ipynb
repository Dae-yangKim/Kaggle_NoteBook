# %% [markdown]
# # Strive to Kaggle NoteBook Expert Project!

# %% [markdown]
# ## Online shop 2023

# %%
# library import

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
plt.rcParams['figure.dpi'] = 150

import missingno as msno
import warnings
warnings.filterwarnings('ignore')

import scipy.stats as st

# %%
# %cd ..
orders = pd.read_csv('./Data/archive/orders.csv')
products = pd.read_csv('./Data/archive/products.csv')
# Out:
# /Users/kengohirano/Desktop/Kaggle/Kaggle_NoteBook/2024.07.11 Online shop 2023

# %% [markdown]
# ### Check the data

# %%
# check the data

orders.head()
# Out:
#    Unnamed: 0  order_id  order_date  product_id  quantity  total_price
# 0           0         1  2023-07-13          24         9      3726.45
# 1           1         2  2023-02-08          75         1       182.71
# 2           2         3  2023-02-14           6         6      2879.58
# 3           3         4  2023-10-07          16         7      2218.37
# 4           4         5  2023-02-03         100        10      3540.80

# %%
products.head()
# Out:
#    Unnamed: 0  product_id   product_name     category   price
# 0           0           1       ubaltprv  Электроника  466.47
# 1           1           2        tDBDlti   Аксессуары  342.91
# 2           2           3  SSoERVQYlXlXo        Книги   44.12
# 3           3           4  bSyPlTJrVTVEn   Аксессуары   15.49
# 4           4           5         OUlXxH   Аксессуары  451.51

# %%
# remove Unnamed: 0

orders.drop(columns = ['Unnamed: 0'] , axis = 1 , inplace = True)
products.drop(columns = ['Unnamed: 0'] , axis = 1 , inplace = True)

# %%
orders.head()
# Out:
#    order_id  order_date  product_id  quantity  total_price
# 0         1  2023-07-13          24         9      3726.45
# 1         2  2023-02-08          75         1       182.71
# 2         3  2023-02-14           6         6      2879.58
# 3         4  2023-10-07          16         7      2218.37
# 4         5  2023-02-03         100        10      3540.80

# %%
products.head()
# Out:
#    product_id   product_name     category   price
# 0           1       ubaltprv  Электроника  466.47
# 1           2        tDBDlti   Аксессуары  342.91
# 2           3  SSoERVQYlXlXo        Книги   44.12
# 3           4  bSyPlTJrVTVEn   Аксессуары   15.49
# 4           5         OUlXxH   Аксессуары  451.51

# %%
print(f"Orders size : {orders.shape}")
print(f"Products size : {products.shape}")
# Out:
# Orders size : (100, 5)
# Products size : (100, 4)

# %%
# merge data

df = pd.merge(orders , products , on = 'product_id')

# %%
df.head()
# Out:
#    order_id  order_date  product_id  quantity  total_price    product_name  \
# 0         1  2023-07-13          24         9      3726.45      YQgQAxnvUD
# 1         2  2023-02-08          75         1       182.71        TIJiEOeS
# 2         3  2023-02-14           6         6      2879.58  dheuOSsoAYqmJz
# 3         4  2023-10-07          16         7      2218.37           gBsuy
# 4         5  2023-02-03         100        10      3540.80         TBvydjC
#
#      category   price
# 0  Аксессуары  414.05
# 1       Книги  182.71
# 2  Аксессуары  479.93
# 3       Книги  316.91
# 4       Книги  354.08

# %%
# show missing values

msno.bar(df)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      100 non-null    int64
#  1   order_date    100 non-null    object
#  2   product_id    100 non-null    int64
#  3   quantity      100 non-null    int64
#  4   total_price   100 non-null    float64
#  5   product_name  100 non-null    object
#  6   category      100 non-null    object
#  7   price         100 non-null    float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 6.4+ KB

# %% [markdown]
# ### Exploratory Data Analysis
